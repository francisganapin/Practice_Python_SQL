# %%
import pandas as pd

# %%
# !pip3 install pandas

# %%
data = pd.read_csv('sales.csv')

# %%
df = pd.DataFrame(data)

# %%
total_sales = df['sales'].sum()
print(total_sales)
# Out:
# 4300

# %%
avg_sales = df['sales'].mean()
print(avg_sales)
# Out:
# 1075.0

# %%
total_customer = df['customer'].sum()
print(total_customer)
# Out:
# 103

# %%
best_day = df.loc[df['sales'].idxmax()]
print(best_day)
# Out:
# day            3
# sales       1500
# customer      35
# Name: 2, dtype: int64

# %%
df['growt_rate'] = df['sales'].pct_change() * 100
print(df['growt_rate'])
# Out:
# 0          NaN
# 1   -25.000000
# 2    66.666667
# 3   -53.333333
# Name: growt_rate, dtype: float64

# %%
df1 = pd.read_csv('datas.csv')


df1['age'] = df1['age'].fillna(df1['age'].mean())
print(df1['age'])
# Out:
# 0    20.000000
# 1    21.000000
# 2    50.000000
# 3    30.333333
# Name: age, dtype: float64

# %%
df1['income'] = df1['income'].astype(int)
print(df1['income'])
# Out:
# 0    10000
# 1    12102
# 2    13605
# 3    74120
# Name: income, dtype: int64

# %%
import matplotlib.pyplot as plt

sales = [1200,900,1500,700,1800]

# %%
plt.plot(sales)
plt.title('sales Trend')
plt.xlabel('Day')
plt.ylabel('Sales')
plt.show()

# %%
df3 = pd.DataFrame({
    'hours':[1,2,3,4,5],
    'score':[50,55,65,70,90]
})

# %%
print(df.corr())
# Out:
#                  day     sales  customer  growt_rate
# day         1.000000 -0.331970 -0.334770   -0.225858
# sales      -0.331970  1.000000  0.984915    0.999891
# customer   -0.334770  0.984915  1.000000    0.992810
# growt_rate -0.225858  0.999891  0.992810    1.000000

# %%
from sklearn.linear_model import LinearRegression

# %%
df = pd.DataFrame({
    "experience": [1, 2, 3, 4, 5],
    "salary": [25, 30, 40, 45, 60]
})

# %%
model = LinearRegression()
model.fit(df[["experience"]], df["salary"])

prediction = model.predict([[6]])
print('Predicted salary:',prediction[0])
# Out:
# Predicted salary: 65.5
# e:\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
