# %%
import pandas as pd

# %%
data = {
    "name":['John',"Maria",'Daniel'],
    "age":[25,30,22],
    "city":['Manila','Cebu','Davao']
}

df = pd.DataFrame(data)
print(df)
# Out:
#      name  age    city
# 0    John   25  Manila
# 1   Maria   30    Cebu
# 2  Daniel   22   Davao

# %%
df = pd.save_csv("data.csv")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df = pd.save_csv("data.csv")
#
# AttributeError: module 'pandas' has no attribute 'save_csv'
